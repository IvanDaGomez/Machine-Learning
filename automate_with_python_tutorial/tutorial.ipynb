# %% [markdown]
# ## Read csv and tables from a webpage

# %%
# %pip install pandas
import pandas as pd # type: ignore

# %%
def read_csv_file(file_path: str) -> pd.DataFrame:
    """
    Reads a CSV file and returns its content as a pandas DataFrame.

    :param file_path: Path to the CSV file.
    :return: DataFrame containing the CSV data.
    """
    try:
        df = pd.read_csv(file_path)
        return df
    except FileNotFoundError:
        print(f"Error: The file {file_path} does not exist.")
        return pd.DataFrame()  # Return an empty DataFrame if the file is not found
    except pd.errors.EmptyDataError:
        print(f"Error: The file {file_path} is empty.")
        return pd.DataFrame()  # Return an empty DataFrame if the file is empty
    except Exception as e:
        print(f"An error occurred while reading the file: {e}")
        return pd.DataFrame()  # Return an empty DataFrame for any other errors

frame = read_csv_file("https://people.sc.fsu.edu/~jburkardt/data/csv/addresses.csv")
frame.head()
# Out:
#                     John       Doe                 120 jefferson st.  \
# 0                   Jack  McGinnis                      220 hobo Av.
# 1          John "Da Man"    Repici                 120 Jefferson St.
# 2                Stephen     Tyler  7452 Terrace "At the Plaza" road
# 3                    NaN  Blankman                               NaN
# 4  Joan "the bone", Anne       Jet               9th, at Terrace plc
#
#      Riverside   NJ   08075
# 0        Phila   PA    9119
# 1    Riverside   NJ    8075
# 2     SomeTown   SD   91234
# 3     SomeTown   SD     298
# 4  Desert City   CO     123

# %%
frame.rename(columns={"John": "first_name", "Doe": "last_name", "120 jefferson st.": "address", "Riverside": "city", "NJ": "state", "08075": "zip"}, inplace=True)
frame.head()
# Out:
#               first_name last_name                           address  \
# 0                   Jack  McGinnis                      220 hobo Av.
# 1          John "Da Man"    Repici                 120 Jefferson St.
# 2                Stephen     Tyler  7452 Terrace "At the Plaza" road
# 3                    NaN  Blankman                               NaN
# 4  Joan "the bone", Anne       Jet               9th, at Terrace plc
#
#           city   NJ   08075
# 0        Phila   PA    9119
# 1    Riverside   NJ    8075
# 2     SomeTown   SD   91234
# 3     SomeTown   SD     298
# 4  Desert City   CO     123

# %% [markdown]
# ## Extract tables from pdf

# %%
# %pip install tk ghostscript camelot-py
import camelot # type: ignore
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.6/66.6 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 29.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 18.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 64.2 MB/s eta 0:00:00
# ...
# /usr/local/lib/python3.11/dist-packages/pypdf/_crypt_providers/_cryptography.py:32: CryptographyDeprecationWarning: ARC4 has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.ARC4 and will be removed from this module in 48.0.0.
#   from cryptography.hazmat.primitives.ciphers.algorithms import AES, ARC4

# %%
tables = camelot.read_pdf('foo.pdf', pages='1')
tables.export('foo.csv', f='csv', compress=True) # json, excel, html
tables[0].to_csv('foo.csv')

# %% [markdown]
# ## Web scraping with xPath
#
# //tagName[@AttributeName="Value"]
# contains()
# strats-with()
# //div[contains(@class, "script")]
# /: Select the children
# //h1/.. -> returns the parent node
# //h1/* -> all the children

# %%
# %pip install selenium

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
website = "https://www.thesun.co.uk/sport/football/"
path = "/" # ~/Documents/Ivan/chromeDriver"

service = Service(executable_path=path)
driver = webdriver.Chrome(service=service)
driver.get(website)

containers = driver.find_elements(by=By.XPATH, value="//h1")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/selenium/webdriver/common/driver_finder.py in _binary_paths(self)
#      63                 if not Path(path).is_file():
# ---> 64                     raise ValueError(f"The path is not a valid file: {path}")
#      65                 self._paths["driver_path"] = path
#
# ValueError: The path is not a valid file: /
#
# The above exception was the direct cause of the following exception:
#
# NoSuchDriverException                     Traceback (most recent call last)
# /tmp/ipython-input-5-1450256613.py in <cell line: 0>()
#       6
#       7 service = Service(executable_path=path)
# ----> 8 driver = webdriver.Chrome(service=service)
#       9 driver.get(website)
#      10
#
# ...
